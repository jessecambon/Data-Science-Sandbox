# %% [markdown]
# Analyze state of the union addresses.
# Data source: https://en.wikisource.org/wiki/Portal:State_of_the_Union_Speeches_by_United_States_Presidents
# scrape the text of all speeches and then maybe try to find patterns of speech of each president?

# %% [markdown]
# https://nlp.stanford.edu/IR-book/html/htmledition/sublinear-tf-scaling-1.html
# https://www.oreilly.com/library/view/applied-text-analysis/9781491963036/ch04.html

# %% [markdown]
# ## Setup

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import urllib.request
import re

from textblob import TextBlob
import seaborn as sns
import matplotlib.pyplot as plt
from gensim.corpora.dictionary import Dictionary
import gensim
from gensim import corpora, models
import spacy
import time
from sklearn.feature_extraction.text import TfidfVectorizer, CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation

# Data source we are going to scrape for results
data_url = 'https://en.wikisource.org/wiki/Portal:State_of_the_Union_Speeches_by_United_States_Presidents'

link_list = []

# extract the text of a speech from a URL
# text is extracted in a list of paragraphs (strings) for each speech
def get_speech(url):
    return([ p.text.strip() for p in BeautifulSoup(urllib.request.urlopen(url)).find_all("p") if \
             'This work is in the public domain in the United States because it is a work of the United States federal government' \
             not in p.text.strip()])

# Make a frequency count by distinct values of 
# column(s) listed in 'groupbyvars'
# Returns pandas dataframe
def tidy_count(df,groupbyvars):
    return(df.groupby(groupbyvars).size().reset_index().\
        rename(columns={0: "n"}).sort_values('n',ascending=False).reset_index(drop=True))

# %% [markdown]
# ## Web Scraping

# %%
resp = urllib.request.urlopen(data_url)
soup = BeautifulSoup(resp, from_encoding=resp.info().get_param('charset'))

# Get all links to state of the union addresses from 
for link in soup.find_all('a', href=True):
    if "union_address" in link['href'].lower() or "union_speech" in link['href'].lower() \
        and "portal" not in link['href'].lower() and "#" not in link['href'].lower():
        link_list.append(link['href'])

# Note that I am storing these speeches as lists of paragraphs (strings) for readability
speeches = [get_speech('https://en.wikisource.org' + link) for link in link_list]
# Extract presidents names from link text
presidents = [ link.replace('%','/').split('/')[2].replace('_',' ') for link in link_list ]

# Extract state of the union text entries so we can extract the date
sou_entries = []
for item in soup.find_all('li'):
    if 'union' in item.text.strip().lower() and '(' in  item.text.strip().lower():
        sou_entries.append(item.text.strip())

speeches_pd = pd.DataFrame({
                'president' : presidents,
                'speech' : speeches,
                'year' : [int(re.findall('\d+',item)[1]) for item in sou_entries ]} )

# %%
speeches_pd.sample(n=5)
# Out:
#                      president  \
# 153  Franklin Delano Roosevelt
# 227               Barack Obama
# 44              Andrew Jackson
# 61            Millard Fillmore
# 79              Andrew Johnson
#
#                                                 speech  year
# 153  [Mr. Vice President, Mr. Speaker, Members of t...  1943
# 227  [Mr. Speaker, Mr. Vice President, Members of C...  2015
# 44   [Fellow Citizens of the Senate and of the Hous...  1833
# 61   [Fellow-Citizens of the Senate and of the Hous...  1850
# 79   [Fellow-Citizens of the Senate and House of Re...  1868

# %% [markdown]
# ## Preprocessing

# %% [markdown]
# Clean text (remove stop words, convert to lower case, remove non-alphabetic text, and lemmatize

# %%
nlp = spacy.load('en', disable=['parser', 'ner']) # disabling the parser makes it run faster
#nlp = spacy.load('en_core_web_lg',disable=['parser', 'ner'])

# Preprocess pipeline with spacy. 
def spacy_preprocess(text): 
    text_out = []
    for token in nlp(text.lower()):
        # Get rid of stop words and non-alphanumeric
        if not token.is_stop and token.is_alpha and len(token)>1:
            lemma = token.lemma_
            if lemma != '-PRON-':
                text_out.append(lemma)
            else:
                text_out.append(token.text)            
    return(text_out)

# %%
# Case sensitivity matters for stop-words for some reason
# So we need to convert all text to lowercase before
# letting spacy see it (as done in above function)
for token in nlp('The the'):
    print(not token.is_stop)
# Out:
# True
# False

# %%
# test spacy preprocessing
spacy_preprocess('The dog ran into Bob beCause he saw 234 squirrels under VAU15')
# Out:
# ['dog', 'run', 'bob', 'see', 'squirrel']

# %%
# Each speech is stored as a list of paragraph strings. 
# Here we join the paragraphs into a single speech string
speech_list = [" ".join(speech) for speech in speeches_pd['speech'].tolist() ]

## Pre-process and tokenize our speeches
start = time.time()
tokens = [spacy_preprocess(speech) for \
          speech in speech_list ]
print('Preprocessing time elapsed: ' + str(time.time()-start))
# Out:
# Preprocessing time elapsed: 58.04954791069031

# %% [markdown]
# ## Gensim Topic Modeling

# %%
# create dictionary and corpus objects for gensim topic modeling
common_dictionary = Dictionary(tokens)
gensim_corpus = [common_dictionary.doc2bow(doc) for doc in tokens]

# %%
start = time.time()
gensimLDA = gensim.models.ldamodel.LdaModel(gensim_corpus,num_topics=12,
        random_state=42, id2word=common_dictionary,passes=10)
print('Gensim LDA training time: ' + str(time.time()-start))
# Out:
# Gensim LDA training time: 35.961342096328735

# %%
# Print the words in each gensim topic without probabilties
# to show probabilites, just use the gensimModel.show_topics() function
def print_gensim_topics(gensimModel,n_words):
    gensim_topic_list = gensimModel.print_topics(num_words=n_words)
    for n, topic in enumerate(gensim_topic_list):
        # Grab words that are in double quotes (ie. strip out probabilities)
        print('topic ' + str(n) + ": " + " ".join(re.findall(r'"(.*?)"', topic[1])))

print_gensim_topics(gensimLDA,18)
#gensimLDA.show_topics()
# Out:
# topic 0: bank congress country government year system increase credit state large tariff law power good people work nation great
# topic 1: people tariff price present duty government increase condition manufacture country law treasury public bond interest pay cent taxation
# topic 2: state year government united congress law country increase report general great present people service act time interest secretary
# topic 3: government state work people year american nation congress country law public great good man america national world time
# topic 4: year american people america new work world nation help congress good time job need country state child government
# topic 5: law government man state great good work country people year public nation business need congress time condition power
# topic 6: man government state law nation people country good great american public case right power matter united war increase
# topic 7: state government congress country year united great public interest service attention subject present department law war report people
# topic 8: government state congress united year country law american department great service public interest present system increase time foreign
# topic 9: state government united congress country public great power year present duty law time subject war interest citizen people
# topic 10: nation government year world people congress great war state program national economic federal need peace increase time new
# topic 11: state government country year nation congress time united great public law power people american war present general service

# %%
doc_top_proportions = [ gensimLDA.get_document_topics(doc,minimum_probability=0) for doc in gensim_corpus ]
doc_top_probs = pd.DataFrame([[prob for (topic, prob) in prob_tuple] for prob_tuple in doc_top_proportions])
doc_top_probs['MostCommonTopic'] = doc_top_probs.idxmax(axis=1)
doc_top_probs[['year','president']] = speeches_pd[['year','president']]

# %% [markdown]
# Topic 10 seems to be related to war and peace, plot the prevalence of the topic

# %%
sns.relplot(x="year",y=10, data=doc_top_probs,kind="line",height=6,aspect=1.5)
#plt.xlim(1995,2018)

# %%
tidy_count(doc_top_probs,'MostCommonTopic')
# Out:
#    MostCommonTopic   n
# 0                9  82
# 1                4  57
# 2               10  43
# 3                2  25
# 4                8  12
# 5                5   6
# 6                7   4
# 7                1   1
# 8                6   1

# %%
doc_top_probs.sample(5)
# Out:
#             0         1         2         3         4         5         6  \
# 155  0.000023  0.000023  0.008885  0.000023  0.408400  0.074654  0.000023
# 12   0.000063  0.000063  0.000063  0.000063  0.000063  0.000063  0.000063
# 169  0.000035  0.000035  0.000035  0.000035  0.247753  0.000035  0.000035
# 81   0.000022  0.000022  0.327150  0.000022  0.000022  0.001950  0.000022
# 215  0.000032  0.000032  0.000032  0.000032  0.993770  0.000032  0.000032
#
#             7         8         9        10        11  MostCommonTopic  year  \
# 155  0.000023  0.000023  0.089156  0.418744  0.000023               10  1945
# 12   0.018878  0.000063  0.980491  0.000063  0.000063                9  1801
# 169  0.000035  0.000035  0.000035  0.751892  0.000035               10  1958
# 81   0.270354  0.004884  0.395506  0.000022  0.000022                9  1870
# 215  0.000032  0.000032  0.005908  0.000032  0.000032                4  2003
#
#                      president
# 155  Franklin Delano Roosevelt
# 12            Thomas Jefferson
# 169       Dwight D. Eisenhower
# 81            Ulysses S. Grant
# 215             George W. Bush

# %%
doc_top_probs.drop('MostCommonTopic',axis=1).idxmax(axis=0)
# Out:
# 0       6
# 1     132
# 2     142
# 3     126
# 4      35
# 5      68
# 6      25
# 7     124
# 8     212
# 9     153
# 10    112
# 11    103
# 12     98
# dtype: int64

# %% [markdown]
# ## SkLearn Topic Modeling

# %%
# Vectorize
#tvec = TfidfVectorizer(tokenizer=None,analyzer='word',
#                        max_df=0.95, min_df=2,
#                        ngram_range=(1,1),max_features=10000)

tf_vectorizer = CountVectorizer(max_df=0.95, min_df=2)
                        #        max_features=10000)
tf = pd.DataFrame(tf_vectorizer.fit_transform([" ".join(doc) for doc in tokens]).toarray(),
                     columns  = tf_vectorizer.get_feature_names())

# %%
tf.shape
# Out:
# (231, 11369)

# %%
## LDA Topic Modeling
speech_lda = LatentDirichletAllocation(n_components=8,
                                       random_state=42,
                                    #   evaluate_every=0.5, # eval perplexity
                                    #   perp_tol=0.05,
                                       max_iter=30,
                                learning_method='online'
                                      )
start = time.time()
speech_lda.fit(tf) # fit model
print('Sklearn LDA training time: ' + str(time.time()-start))
# Out:
# Sklearn LDA training time: 20.58245086669922

# %%
# Print the top words for topics in the topic model
def print_top_words(model, feature_names, n_top_words):
    for topic_idx, topic in enumerate(model.components_):
        message = "Topic %d: " % topic_idx
        message += " ".join([feature_names[i]
                             for i in topic.argsort()[:-n_top_words - 1:-1]])
        print(message)
    print()    

print_top_words(speech_lda, tf.columns.values, 20)
# Out:
# Topic 0: present duty subject citizen treaty general shall constitution treasury territory mexico necessary measure union effect receive require object increase foreign
# Topic 1: department american increase service present work man general report condition result large duty land court question subject secretary legislation foreign
# Topic 2: duty subject general department service treaty present increase purpose treasury foreign condition place consideration necessary citizen system secretary exist object
# Topic 3: present citizen american department subject system service increase general question constitution work duty condition treaty consideration necessary man foreign result
# Topic 4: american america work world help job child need know tax let tonight family ask program come security economy life high
# Topic 5: present subject citizen duty foreign condition report department general shall service increase american consideration attention commerce treaty man necessary provision
# Topic 6: duty shall citizen american general department present claim subject mexico question necessary report increase treaty service treasury purpose require pay
# Topic 7: world program federal increase need economic policy shall work problem system effort service action security present man million legislation price

# %%
# % makeup of each document by topic
doc_topic = pd.DataFrame(speech_lda.transform(tf),
                        columns=list(range(0,(speech_lda.n_components))))

# What was the most common topic in each document?
doc_topic['MostCommonTopic'] = doc_topic.idxmax(axis=1)
doc_topic[['year','president']] = speeches_pd[['year','president']]

# %%
tidy_count(doc_topic,'MostCommonTopic')
# Out:
#    MostCommonTopic   n
# 0                0  80
# 1                4  54
# 2                7  52
# 3                1  45

# %%
# In which document did each topic most commonly occur?
doc_topic.drop('president',axis=1).idxmax(axis=0)
# Out:
# 0                   57
# 1                  103
# 2                    0
# 3                    0
# 4                  212
# 5                    0
# 6                    0
# 7                  156
# MostCommonTopic    124
# year               230
# dtype: int64

# %%
import seaborn as sns
cm = sns.light_palette("green", as_cmap=True)

# %%
president_topic = doc_topic.drop(['MostCommonTopic','year'],axis=1).groupby('president').agg('mean')

# %%
president_topic.sample(15).style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_49440e78_396d_11e9_a137_495451a163aarow0_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col2 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col3 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col4 {
#             background-color:  #82c882;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col5 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col6 {
#             background-color:  #c2ebc2;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow0_col7 {
#             background-color:  #319b31;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col0 {
#             background-color:  #9dd79d;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col1 {
#             background-color:  #3ca13c;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col2 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col3 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col5 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col6 {
#             background-color:  #dcfadc;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col0 {
#             background-color:  #c8efc8;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col1 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col2 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col3 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col5 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col6 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow2_col7 {
#             background-color:  #e2fde2;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col0 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col2 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col3 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col4 {
#             background-color:  #128a12;
#             color:  #f1f1f1;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col5 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col6 {
#             background-color:  #aee0ae;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow3_col7 {
#             background-color:  #cff3cf;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col0 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col1 {
#             background-color:  #a4dba4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col2 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col3 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col5 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col6 {
#             background-color:  #bfeabf;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow4_col7 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col0 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col2 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col3 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col4 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col5 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col6 {
#             background-color:  #b9e7b9;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow5_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col0 {
#             background-color:  #b0e2b0;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col1 {
#             background-color:  #289628;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col2 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col3 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col5 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col6 {
#             background-color:  #daf9da;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow6_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow7_col0 {
#             background-color:  #018001;
#             color:  #f1f1f1;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow7_col1 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow7_col2 {
#             background-color:  #d8f8d8;
#             color:  #000000;
#         }    #T_49440e78_396d_11e9_a137_495451a163aarow7_col3 {
#             background-color:  #d8f8d8;
#             color:  #000000;

# %%
doc_topic.style.background_gradient(cmap=cm)
# Out:
# <style  type="text/css" >
#     #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col2 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col3 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col5 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col6 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow0_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col2 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col3 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col5 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col6 {
#             background-color:  #329c32;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow1_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col2 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col3 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col5 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col6 {
#             background-color:  #7dc57d;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow2_col9 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col2 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col3 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col5 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col6 {
#             background-color:  #73c073;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow3_col9 {
#             background-color:  #e4fee4;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col2 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col3 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col5 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col6 {
#             background-color:  #64b764;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow4_col9 {
#             background-color:  #e3fee3;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col0 {
#             background-color:  #008000;
#             color:  #f1f1f1;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col1 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col2 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col3 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col4 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col5 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col6 {
#             background-color:  #95d395;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col7 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col8 {
#             background-color:  #e5ffe5;
#             color:  #000000;
#         }    #T_4437b5ba_396d_11e9_a137_495451a163aarow5_col9 {
#             background-color:  #e2fde2;
#             color:  #000000;

# %% [markdown]
# Topic 7 seems to be related to economic programs, let's plot the prevalence of that topic over time

# %%
sns.relplot(x="year",y=7,data=doc_topic,kind="line",height=6,aspect=1.5)
#plt.xlim(1900,2000)
# Out:
# /home/cambonator/anaconda3/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %% [markdown]
# ## Predict Year of Address

# %%
from sklearn.linear_model import LassoCV
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error

X = doc_topic.drop(['MostCommonTopic','president','year'],axis=1)
y = doc_topic['year']

X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.3, random_state=0)

# %%
LASSOreg = LassoCV(cv=5, random_state=0).fit(X_train, y_train)

# Print train and test R^2
print(LASSOreg.score(X_train,y_train))
print(LASSOreg.score(X_test,y_test))
# Out:
# 0.9627224538161774
# 0.9549325190928816

# %%
mean_absolute_error(LASSOreg.predict(X_test),y_test)
# Out:
# 10.416296136883817

# %%
# Obtain pandas dataframe of model coefficients sorted by value
# To do : sort by absolute value
def obtain_coefficients(model):
    coefficients = pd.DataFrame(model.coef_.T)
    coefficients.insert(0,'',list(X.columns.values))
    coefficients.columns = ['term','coefficient']
    coefficients.sort_values(by='coefficient',ascending=False,inplace=True)
    return(coefficients)

obtain_coefficients(LASSOreg)
# Out:
#    term  coefficient
# 4     4    61.236741
# 7     7     0.001434
# 2     2    -0.000000
# 3     3    -0.000000
# 5     5    -0.000000
# 6     6    -0.000000
# 1     1   -36.118713
# 0     0  -113.990742

# %% [markdown]
# According to the model, topic 4 is associated with more recent addresses while topics 1 and 0 are associated with older addresses.
# Topic 4 has personal terms such as 'child','family', and 'job' while topics 0 and 1 seem to be more associated with legislation and policy.

# %% [markdown]
# ## Sentiment Analysis

# %%
sentiments = [TextBlob(text).sentiment for text in speech_list ] 

speeches_pd['polarity'] = [ i[0] for i in sentiments]
speeches_pd['subjectivity'] = [ i[1] for i in sentiments]

# %%
sns.relplot(x="year", y="polarity", data=speeches_pd,kind="line",height=6,aspect=1.5)
